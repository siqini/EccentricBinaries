# %%
import sys
# !{sys.executable} -m pip install pycbc lalsuite ligo-common --no-cache-dir
# Out:
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7.
# Collecting pycbc
#   Downloading https://files.pythonhosted.org/packages/86/ef/0ec0220f6f12f404e964b262859eb047297caa1126805600930367e7d548/PyCBC-1.14.0.tar.gz (3.0MB)
#      |████████████████████████████████| 3.0MB 4.0MB/s eta 0:00:01
# Collecting lalsuite
#   Downloading https://files.pythonhosted.org/packages/68/7e/db18150df4e3824a3d871f5cd672cadf220a6d3696597d4598ba677c1391/lalsuite-6.57-cp27-cp27m-macosx_10_12_x86_64.whl (26.5MB)
#      |████████████████████████████████| 26.5MB 64.2MB/s eta 0:00:01
# Collecting ligo-common
#   Downloading https://files.pythonhosted.org/packages/a6/9c/1fbe176feea9abad5c0f3fa090dcffccf44bbcba0f0c754b03d8fea1a36e/ligo_common-1.0.3-py2.py3-none-any.whl
# Collecting Mako>=1.0.1 (from pycbc)
#   Downloading https://files.pythonhosted.org/packages/0a/af/a6d8aa7b8909a36074f517b15222e3a2fbd5ef3452c0a686e3d43043dd3b/Mako-1.0.12.tar.gz (460kB)
#      |████████████████████████████████| 460kB 29.8MB/s eta 0:00:01
# Collecting cython (from pycbc)
#   Downloading https://files.pythonhosted.org/packages/10/4c/fbece7a434ab5f8038d71012642279723640f26a52b38e439af16ccf45a1/Cython-0.29.10-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (2.8MB)
#      |████████████████████████████████| 2.8MB 32.1MB/s eta 0:00:01
# Requirement already satisfied: decorator>=3.4.2 in /anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages (from pycbc) (4.4.0)
# Collecting matplotlib>=1.5.1 (from pycbc)
#   Downloading https://files.pythonhosted.org/packages/3e/d6/4c949597c4186599cc8be08cd11b1e83fe7966676aeee3868bf3e581d852/matplotlib-2.2.4-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (14.0MB)
#      |████████████████████████████████| 14.0MB 15.0MB/s eta 0:00:01
# Collecting pillow (from pycbc)
#   Downloading https://files.pythonhosted.org/packages/61/88/fc486aa50f733ce6c94e58637df61a9f0859aa9bc5d110d765a8d59f8000/Pillow-6.0.0-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.7MB)
#      |████████████████████████████████| 3.7MB 16.3MB/s eta 0:00:01
# Collecting h5py>=2.5 (from pycbc)
#   Downloading https://files.pythonhosted.org/packages/98/06/0e711ae0c95d92ec238218448a15c23590cb117ded59e4bfa322b085b59e/h5py-2.9.0-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (6.1MB)
#      |████████████████████████████████| 6.1MB 11.9MB/s eta 0:00:01
# Collecting jinja2 (from pycbc)
#   Downloading https://files.pythonhosted.org/packages/1d/e7/fd8b501e7a6dfe492a433deb7b9d833d39ca74916fa8bc63dd1a4947a671/Jinja2-2.10.1-py2.py3-none-any.whl (124kB)
#      |████████████████████████████████| 133kB 28.7MB/s eta 0:00:01
# Collecting mpld3>=0.3 (from pycbc)
#   Downloading https://files.pythonhosted.org/packages/91/95/a52d3a83d0a29ba0d6898f6727e9858fe7a43f6c2ce81a5fe7e05f0f4912/mpld3-0.3.tar.gz (788kB)
#      |████████████████████████████████| 798kB 19.9MB/s eta 0:00:01
# Collecting lscsoft-glue>=1.59.3 (from pycbc)
#   Downloading https://files.pythonhosted.org/packages/3b/65/e93853bc1876516db8d58f4590dba1d6b85eaf9d1bd375926ac7897e525a/lscsoft-glue-2.0.0.tar.gz (1.6MB)
#      |████████████████████████████████| 1.6MB 30.2MB/s eta 0:00:01
# Collecting emcee==2.2.1 (from pycbc)
#   Downloading https://files.pythonhosted.org/packages/3f/d3/7635106605dedccd08705beac53be4c43a8da1caad6be667adbf93ed0965/emcee-2.2.1.tar.gz
# Collecting requests>=1.2.1 (from pycbc)
#   Downloading https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 26.0MB/s eta 0:00:01
# Collecting beautifulsoup4>=4.6.0 (from pycbc)
#   Downloading https://files.pythonhosted.org/packages/8b/0e/048a2f88bc4be5e3697df9dc1f7b9d5c9c75be62676feeeb91d2e896c5ea/beautifulsoup4-4.7.1-py2-none-any.whl (94kB)
#      |████████████████████████████████| 102kB 28.0MB/s ta 0:00:01
# Requirement already satisfied: six>=1.10.0 in /anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages (from pycbc) (1.12.0)
# Collecting ligo-segments (from pycbc)
#   Downloading https://files.pythonhosted.org/packages/62/cd/225e331e95cf6aff8ba13bf9a8053b29248a5e71f7fa9bbb1f0db1eaadff/ligo-segments-1.2.0.tar.gz (48kB)
#      |████████████████████████████████| 51kB 24.1MB/s eta 0:00:01
# Collecting numpy<1.15.3,>=1.13.0 (from pycbc)
#   Downloading https://files.pythonhosted.org/packages/d6/47/447d4e08e18c4f0e7f935db24d8afcfc9026a84002c0e5d85103c14baaf1/numpy-1.15.2-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (24.5MB)
#      |████████████████████████████████| 24.5MB 8.3MB/s eta 0:00:011
# Collecting astropy<3.0.0,>=2.0.3 (from pycbc)
#   Downloading https://files.pythonhosted.org/packages/3b/f5/d3a8cc881e5e38fb974856714ca03b6632a0f40e2392e43a58f534abf56e/astropy-2.0.14-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (7.8MB)
#      |████████████████████████████████| 7.8MB 15.6MB/s eta 0:00:01
# Collecting weave>=0.16.0 (from pycbc)
#   Downloading https://files.pythonhosted.org/packages/8f/1f/ad729315589f5b23cd449c9f920717004ba47d06887cfc2f0740bd56767d/weave-0.17.0.tar.gz (573kB)
#      |████████████████████████████████| 583kB 23.5MB/s eta 0:00:01
# Collecting scipy<1.3.0,>=0.16.0 (from pycbc)
#   Downloading https://files.pythonhosted.org/packages/a3/cf/36b77de4ccb1b841acd4c3c03abe38843c63c3a657cedee9e8fb19a02dc8/scipy-1.2.2-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (27.4MB)
#      |████████████████████████████████| 27.4MB 3.5MB/s eta 0:00:011
# Requirement already satisfied: python-dateutil in /anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages (from lalsuite) (2.8.0)
# Collecting MarkupSafe>=0.9.2 (from Mako>=1.0.1->pycbc)
#   Downloading https://files.pythonhosted.org/packages/6d/d2/0ccd2c0e2cd93b35e765d9b3205cd6602e6b202b522fc7997531353715b3/MarkupSafe-1.1.1-cp27-cp27m-macosx_10_6_intel.whl
# Collecting cycler>=0.10 (from matplotlib>=1.5.1->pycbc)
#   Downloading https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Collecting kiwisolver>=1.0.1 (from matplotlib>=1.5.1->pycbc)
#   Downloading https://files.pythonhosted.org/packages/0d/15/ec5f70ac79f378ed0ef5ed8b71e8a04e382115426b2cda9a3ab5ffcf467f/kiwisolver-1.1.0-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (115kB)
#      |████████████████████████████████| 122kB 17.6MB/s eta 0:00:01
# Collecting pytz (from matplotlib>=1.5.1->pycbc)
#   Downloading https://files.pythonhosted.org/packages/3d/73/fe30c2daaaa0713420d0382b16fbb761409f532c56bdcc514bf7b6262bb6/pytz-2019.1-py2.py3-none-any.whl (510kB)
#      |████████████████████████████████| 512kB 21.8MB/s eta 0:00:01
# Collecting subprocess32 (from matplotlib>=1.5.1->pycbc)
#   Downloading https://files.pythonhosted.org/packages/35/f3/7cdeeef9cb05c42fadcc8aa040dd3b80d94e0f6a8dedc4bacebf796c2385/subprocess32-3.5.4-cp27-cp27m-macosx_10_6_intel.whl
# Collecting backports.functools-lru-cache (from matplotlib>=1.5.1->pycbc)
#   Downloading https://files.pythonhosted.org/packages/03/8e/2424c0e65c4a066e28f539364deee49b6451f8fcd4f718fefa50cc3dcf48/backports.functools_lru_cache-1.5-py2.py3-none-any.whl
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 (from matplotlib>=1.5.1->pycbc)
#   Downloading https://files.pythonhosted.org/packages/dd/d9/3ec19e966301a6e25769976999bd7bbe552016f0d32b577dc9d63d2e0c49/pyparsing-2.4.0-py2.py3-none-any.whl (62kB)
#      |████████████████████████████████| 71kB 27.5MB/s eta 0:00:01
# Collecting pyOpenSSL (from lscsoft-glue>=1.59.3->pycbc)
#   Downloading https://files.pythonhosted.org/packages/01/c8/ceb170d81bd3941cbeb9940fc6cc2ef2ca4288d0ca8929ea4db5905d904d/pyOpenSSL-19.0.0-py2.py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 8.5MB/s eta 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages (from requests>=1.2.1->pycbc) (2019.3.9)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 (from requests>=1.2.1->pycbc)
#   Downloading https://files.pythonhosted.org/packages/e6/60/247f23a7121ae632d62811ba7f273d0e58972d75e58a94d329d51550a47d/urllib3-1.25.3-py2.py3-none-any.whl (150kB)
#      |████████████████████████████████| 153kB 37.8MB/s eta 0:00:01
# Collecting idna<2.9,>=2.5 (from requests>=1.2.1->pycbc)
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 18.3MB/s eta 0:00:01
# Collecting chardet<3.1.0,>=3.0.2 (from requests>=1.2.1->pycbc)
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
#      |████████████████████████████████| 143kB 22.2MB/s eta 0:00:01
# Collecting soupsieve>=1.2 (from beautifulsoup4>=4.6.0->pycbc)
#   Downloading https://files.pythonhosted.org/packages/b9/a5/7ea40d0f8676bde6e464a6435a48bc5db09b1a8f4f06d41dd997b8f3c616/soupsieve-1.9.1-py2.py3-none-any.whl
# Collecting pytest<3.7,>=2.8 (from astropy<3.0.0,>=2.0.3->pycbc)
#   Downloading https://files.pythonhosted.org/packages/d8/e9/73246a565c34c5f203dd78bc2382e0e93aa7a249cdaeba709099eb1bc701/pytest-3.6.4-py2.py3-none-any.whl (196kB)
#      |████████████████████████████████| 204kB 22.9MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=1.5.1->pycbc) (41.0.1)
# Collecting cryptography>=2.3 (from pyOpenSSL->lscsoft-glue>=1.59.3->pycbc)
#   Downloading https://files.pythonhosted.org/packages/e2/bf/3b641820c561aedde134e88528ba68dffe41ed238899fab7f7ef20118aaf/cryptography-2.7-cp27-cp27m-macosx_10_6_intel.whl (1.6MB)
#      |████████████████████████████████| 1.6MB 27.4MB/s eta 0:00:01
# Collecting attrs>=17.4.0 (from pytest<3.7,>=2.8->astropy<3.0.0,>=2.0.3->pycbc)
#   Downloading https://files.pythonhosted.org/packages/23/96/d828354fa2dbdf216eaa7b7de0db692f12c234f7ef888cc14980ef40d1d2/attrs-19.1.0-py2.py3-none-any.whl
# Collecting more-itertools>=4.0.0 (from pytest<3.7,>=2.8->astropy<3.0.0,>=2.0.3->pycbc)
#   Downloading https://files.pythonhosted.org/packages/2f/9d/dcfe59e213093695f108508af1214cf9cd95cc5489e46877ec5cb56369e5/more_itertools-5.0.0-py2-none-any.whl (52kB)
#      |████████████████████████████████| 61kB 35.5MB/s eta 0:00:01
# Collecting funcsigs; python_version < "3.0" (from pytest<3.7,>=2.8->astropy<3.0.0,>=2.0.3->pycbc)
#   Downloading https://files.pythonhosted.org/packages/69/cb/f5be453359271714c01b9bd06126eaf2e368f1fddfff30818754b5ac2328/funcsigs-1.0.2-py2.py3-none-any.whl
# Collecting py>=1.5.0 (from pytest<3.7,>=2.8->astropy<3.0.0,>=2.0.3->pycbc)
#   Downloading https://files.pythonhosted.org/packages/76/bc/394ad449851729244a97857ee14d7cba61ddb268dce3db538ba2f2ba1f0f/py-1.8.0-py2.py3-none-any.whl (83kB)
#      |████████████████████████████████| 92kB 35.3MB/s eta 0:00:01
# Collecting atomicwrites>=1.0 (from pytest<3.7,>=2.8->astropy<3.0.0,>=2.0.3->pycbc)
#   Downloading https://files.pythonhosted.org/packages/52/90/6155aa926f43f2b2a22b01be7241be3bfd1ceaf7d0b3267213e8127d41f4/atomicwrites-1.3.0-py2.py3-none-any.whl
# Collecting pluggy<0.8,>=0.5 (from pytest<3.7,>=2.8->astropy<3.0.0,>=2.0.3->pycbc)
#   Downloading https://files.pythonhosted.org/packages/f5/f1/5a93c118663896d83f7bcbfb7f657ce1d0c0d617e6b4a443a53abcc658ca/pluggy-0.7.1-py2.py3-none-any.whl
# Requirement already satisfied: enum34; python_version < "3" in /anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages (from cryptography>=2.3->pyOpenSSL->lscsoft-glue>=1.59.3->pycbc) (1.1.6)
# Collecting asn1crypto>=0.21.0 (from cryptography>=2.3->pyOpenSSL->lscsoft-glue>=1.59.3->pycbc)
#   Downloading https://files.pythonhosted.org/packages/ea/cd/35485615f45f30a510576f1a56d1e0a7ad7bd8ab5ed7cdc600ef7cd06222/asn1crypto-0.24.0-py2.py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 22.0MB/s ta 0:00:01
# Collecting ipaddress; python_version < "3" (from cryptography>=2.3->pyOpenSSL->lscsoft-glue>=1.59.3->pycbc)
#   Downloading https://files.pythonhosted.org/packages/fc/d0/7fc3a811e011d4b388be48a0e381db8d990042df54aa4ef4599a31d39853/ipaddress-1.0.22-py2.py3-none-any.whl
# Collecting cffi!=1.11.3,>=1.8 (from cryptography>=2.3->pyOpenSSL->lscsoft-glue>=1.59.3->pycbc)
#   Downloading https://files.pythonhosted.org/packages/16/f6/46a3dece43541b2cbf3776ec2299e370a2408d9380958401cacb6d101853/cffi-1.12.3-cp27-cp27m-macosx_10_6_intel.whl (245kB)
#      |████████████████████████████████| 256kB 27.4MB/s eta 0:00:01
# Collecting pycparser (from cffi!=1.11.3,>=1.8->cryptography>=2.3->pyOpenSSL->lscsoft-glue>=1.59.3->pycbc)
#   Downloading https://files.pythonhosted.org/packages/68/9e/49196946aee219aead1290e00d1e7fdeab8567783e83e1b9ab5585e6206a/pycparser-2.19.tar.gz (158kB)
#      |████████████████████████████████| 163kB 29.3MB/s eta 0:00:01
# Building wheels for collected packages: pycbc, Mako, mpld3, lscsoft-glue, emcee, ligo-segments, weave, pycparser
#   Building wheel for pycbc (setup.py) ... error
#   ERROR: Complete output from command /anaconda3/envs/ipykernel_py2/bin/python -u -c 'import setuptools, tokenize;__file__='"'"'/private/var/folders/11/2p7k6f954msg2qh4pzr5ftd40000gn/T/pip-install-9zYL_u/pycbc/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/11/2p7k6f954msg2qh4pzr5ftd40000gn/T/pip-wheel-_wC9xH --python-tag cp27:
#   ERROR: PyCBC.libutils: pkg-config call failed, setting NO_PKGCONFIG=1
#   /anaconda3/envs/ipykernel_py2/lib/python2.7/distutils/extension.py:133: UserWarning: Unknown Extension options: 'compiler_directives'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.6-x86_64-2.7
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/detector.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/transforms.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/version.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/bin_utils.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/_version.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/boundaries.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/conversions.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/rate.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/weave.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/dq.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/opt.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/sensitivity.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/pnutils.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/_version_helper.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/pool.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/cosmology.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/libutils.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/scheme.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   copying pycbc/coordinates.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/types
#   copying pycbc/types/array_cuda.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/types
#   copying pycbc/types/frequencyseries.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/types
#   copying pycbc/types/aligned.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/types
#   copying pycbc/types/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/types
#   copying pycbc/types/optparse.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/types
#   copying pycbc/types/array.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/types
#   copying pycbc/types/timeseries.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/types
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/strain
#   copying pycbc/strain/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/strain
#   copying pycbc/strain/lines.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/strain
#   copying pycbc/strain/gate.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/strain
#   copying pycbc/strain/recalibrate.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/strain
#   copying pycbc/strain/strain.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/strain
#   copying pycbc/strain/calibration.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/strain
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/inject
#   copying pycbc/inject/injfilterrejector.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inject
#   copying pycbc/inject/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inject
#   copying pycbc/inject/inject.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inject
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/psd
#   copying pycbc/psd/analytical.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/psd
#   copying pycbc/psd/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/psd
#   copying pycbc/psd/estimate.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/psd
#   copying pycbc/psd/variation.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/psd
#   copying pycbc/psd/read.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/psd
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/tmpltbank
#   copying pycbc/tmpltbank/bank_output_utils.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/tmpltbank
#   copying pycbc/tmpltbank/lattice_utils.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/tmpltbank
#   copying pycbc/tmpltbank/coord_utils.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/tmpltbank
#   copying pycbc/tmpltbank/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/tmpltbank
#   copying pycbc/tmpltbank/lambda_mapping.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/tmpltbank
#   copying pycbc/tmpltbank/em_progenitors.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/tmpltbank
#   copying pycbc/tmpltbank/partitioned_bank.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/tmpltbank
#   copying pycbc/tmpltbank/option_utils.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/tmpltbank
#   copying pycbc/tmpltbank/brute_force_methods.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/tmpltbank
#   copying pycbc/tmpltbank/calc_moments.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/tmpltbank
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/catalog
#   copying pycbc/catalog/catalog.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/catalog
#   copying pycbc/catalog/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/catalog
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/io
#   copying pycbc/io/hdf.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/io
#   copying pycbc/io/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/io
#   copying pycbc/io/record.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/io
#   copying pycbc/io/live.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/io
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/frame
#   copying pycbc/frame/store.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/frame
#   copying pycbc/frame/losc.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/frame
#   copying pycbc/frame/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/frame
#   copying pycbc/frame/frame.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/frame
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/population
#   copying pycbc/population/rates_functions.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/population
#   copying pycbc/population/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/population
#   copying pycbc/population/scale_injections.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/population
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results
#   copying pycbc/results/str_utils.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results
#   copying pycbc/results/plot.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results
#   copying pycbc/results/color.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results
#   copying pycbc/results/metadata.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results
#   copying pycbc/results/render.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results
#   copying pycbc/results/legacy_grb.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results
#   copying pycbc/results/layout.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results
#   copying pycbc/results/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results
#   copying pycbc/results/dq.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results
#   copying pycbc/results/mpld3_utils.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results
#   copying pycbc/results/scatter_histograms.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results
#   copying pycbc/results/followup.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results
#   copying pycbc/results/versioning.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results
#   copying pycbc/results/table.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/noise
#   copying pycbc/noise/reproduceable.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/noise
#   copying pycbc/noise/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/noise
#   copying pycbc/noise/gaussian.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/noise
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/injection.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/coincidence.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/minifollowups.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/datafind.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/splittable.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/configuration.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/pegasus_workflow.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/inference_followups.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/matched_filter.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/plotting.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/core.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/tmpltbank.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/psdfiles.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/grb_utils.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/jobsetup.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/psd.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/segment.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   copying pycbc/workflow/configparser_test.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/inference
#   copying pycbc/inference/gelman_rubin.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference
#   copying pycbc/inference/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference
#   copying pycbc/inference/geweke.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference
#   copying pycbc/inference/option_utils.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference
#   copying pycbc/inference/evidence.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference
#   copying pycbc/inference/burn_in.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference
#   copying pycbc/inference/entropy.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/fft
#   copying pycbc/fft/cufft.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/fft
#   copying pycbc/fft/backend_support.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/fft
#   copying pycbc/fft/parser_support.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/fft
#   copying pycbc/fft/mkl.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/fft
#   copying pycbc/fft/backend_cuda.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/fft
#   copying pycbc/fft/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/fft
#   copying pycbc/fft/backend_mkl.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/fft
#   copying pycbc/fft/core.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/fft
#   copying pycbc/fft/cuda_pyfft.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/fft
#   copying pycbc/fft/backend_cpu.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/fft
#   copying pycbc/fft/fft_callback.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/fft
#   copying pycbc/fft/fftw_pruned.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/fft
#   copying pycbc/fft/npfft.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/fft
#   copying pycbc/fft/func_api.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/fft
#   copying pycbc/fft/fftw.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/fft
#   copying pycbc/fft/class_api.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/fft
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/filter
#   copying pycbc/filter/matchedfilter.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/filter
#   copying pycbc/filter/fotonfilter.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/filter
#   copying pycbc/filter/resample.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/filter
#   copying pycbc/filter/matchedfilter_numpy.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/filter
#   copying pycbc/filter/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/filter
#   copying pycbc/filter/zpk.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/filter
#   copying pycbc/filter/matchedfilter_cuda.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/filter
#   copying pycbc/filter/autocorrelation.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/filter
#   copying pycbc/filter/qtransform.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/filter
#   copying pycbc/filter/simd_correlate.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/filter
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/events
#   copying pycbc/events/coinc.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/events
#   copying pycbc/events/triggers.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/events
#   copying pycbc/events/eventmgr.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/events
#   copying pycbc/events/threshold_cuda.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/events
#   copying pycbc/events/single.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/events
#   copying pycbc/events/simd_threshold.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/events
#   copying pycbc/events/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/events
#   copying pycbc/events/coinc_rate.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/events
#   copying pycbc/events/trigger_fits.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/events
#   copying pycbc/events/stat.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/events
#   copying pycbc/events/veto.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/events
#   copying pycbc/events/threshold_cpu.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/events
#   copying pycbc/events/ranking.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/events
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   copying pycbc/waveform/waveform.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   copying pycbc/waveform/spa_tmplt_cuda.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   copying pycbc/waveform/pycbc_phenomC_tmplt.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   copying pycbc/waveform/ringdown.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   copying pycbc/waveform/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   copying pycbc/waveform/bank.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   copying pycbc/waveform/generator.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   copying pycbc/waveform/decompress_cpu.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   copying pycbc/waveform/spa_tmplt.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   copying pycbc/waveform/utils.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   copying pycbc/waveform/compress.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   copying pycbc/waveform/decompress_cuda.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   copying pycbc/waveform/parameters.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   copying pycbc/waveform/nltides.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   copying pycbc/waveform/utils_cuda.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   copying pycbc/waveform/SpinTaylorF2.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   copying pycbc/waveform/sinegauss.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/waveform
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/distributions
#   copying pycbc/distributions/bounded.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/distributions
#   copying pycbc/distributions/angular.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/distributions
#   copying pycbc/distributions/uniform_log.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/distributions
#   copying pycbc/distributions/arbitrary.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/distributions
#   copying pycbc/distributions/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/distributions
#   copying pycbc/distributions/power_law.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/distributions
#   copying pycbc/distributions/joint.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/distributions
#   copying pycbc/distributions/constraints.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/distributions
#   copying pycbc/distributions/uniform.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/distributions
#   copying pycbc/distributions/sky_location.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/distributions
#   copying pycbc/distributions/spins.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/distributions
#   copying pycbc/distributions/gaussian.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/distributions
#   copying pycbc/distributions/qnm.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/distributions
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/vetoes
#   copying pycbc/vetoes/bank_chisq.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/vetoes
#   copying pycbc/vetoes/sgchisq.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/vetoes
#   copying pycbc/vetoes/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/vetoes
#   copying pycbc/vetoes/chisq_cuda.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/vetoes
#   copying pycbc/vetoes/chisq.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/vetoes
#   copying pycbc/vetoes/autochisq.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/vetoes
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/io
#   copying pycbc/inference/io/emcee_pt.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/io
#   copying pycbc/inference/io/emcee.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/io
#   copying pycbc/inference/io/base_sampler.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/io
#   copying pycbc/inference/io/base_multitemper.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/io
#   copying pycbc/inference/io/txt.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/io
#   copying pycbc/inference/io/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/io
#   copying pycbc/inference/io/cpnest.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/io
#   copying pycbc/inference/io/posterior.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/io
#   copying pycbc/inference/io/base_hdf.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/io
#   copying pycbc/inference/io/base_mcmc.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/io
#   copying pycbc/inference/io/multinest.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/io
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/models
#   copying pycbc/inference/models/marginalized_gaussian_noise.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/models
#   copying pycbc/inference/models/single_template.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/models
#   copying pycbc/inference/models/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/models
#   copying pycbc/inference/models/base_data.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/models
#   copying pycbc/inference/models/gaussian_noise.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/models
#   copying pycbc/inference/models/analytic.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/models
#   copying pycbc/inference/models/base.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/models
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/sampler
#   copying pycbc/inference/sampler/emcee_pt.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/sampler
#   copying pycbc/inference/sampler/emcee.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/sampler
#   copying pycbc/inference/sampler/base_multitemper.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/sampler
#   copying pycbc/inference/sampler/__init__.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/sampler
#   copying pycbc/inference/sampler/cpnest.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/sampler
#   copying pycbc/inference/sampler/base_mcmc.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/sampler
#   copying pycbc/inference/sampler/base.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/sampler
#   copying pycbc/inference/sampler/multinest.py -> build/lib.macosx-10.6-x86_64-2.7/pycbc/inference/sampler
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/tmpltbank/ns_sequences
#   copying pycbc/tmpltbank/ns_sequences/equil_2H.dat -> build/lib.macosx-10.6-x86_64-2.7/pycbc/tmpltbank/ns_sequences
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/css
#   copying pycbc/results/static/css/bootstrap.min.css -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/css
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/css/pycbc
#   copying pycbc/results/static/css/pycbc/orange.css -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/css/pycbc
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/css/bootstrap
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/css/bootstrap/3.3.2
#   copying pycbc/results/static/css/bootstrap/3.3.2/bootstrap.min.css -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/css/bootstrap/3.3.2
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/css/fancybox
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/css/fancybox/2.1.5
#   copying pycbc/results/static/css/fancybox/2.1.5/jquery.fancybox.css -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/css/fancybox/2.1.5
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/js
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/js/bootstrap
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/js/bootstrap/3.3.2
#   copying pycbc/results/static/js/bootstrap/3.3.2/bootstrap.min.js -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/js/bootstrap/3.3.2
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/js/fancybox
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/js/fancybox/2.1.5
#   copying pycbc/results/static/js/fancybox/2.1.5/jquery.fancybox.pack.js -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/js/fancybox/2.1.5
#   copying pycbc/results/static/js/fancybox/2.1.5/jquery.fancybox.js -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/js/fancybox/2.1.5
#   copying pycbc/results/static/js/fancybox/2.1.5/fancybox-orange.js -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/js/fancybox/2.1.5
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/js/jquery
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/js/jquery/1.10.2
#   copying pycbc/results/static/js/jquery/1.10.2/jquery.mousewheel-3.0.6.pack.js -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/js/jquery/1.10.2
#   copying pycbc/results/static/js/jquery/1.10.2/jquery-1.10.2.min.js -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/js/jquery/1.10.2
#   copying pycbc/results/static/js/jquery.min.js -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/js
#   copying pycbc/results/static/js/bootstrap.min.js -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/js
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/fonts
#   copying pycbc/results/static/fonts/Lato-Light.html -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/fonts
#   copying pycbc/results/static/fonts/Lato-Semibold.eot -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/fonts
#   copying pycbc/results/static/fonts/Lato-Semibold.html -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/fonts
#   copying pycbc/results/static/fonts/Lato-Light.css -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/fonts
#   copying pycbc/results/static/fonts/Lato-Semibold.ttf -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/fonts
#   copying pycbc/results/static/fonts/Lato-Light.eot -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/fonts
#   copying pycbc/results/static/fonts/Lato-Semibold.woff -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/fonts
#   copying pycbc/results/static/fonts/Lato-Light.ttf -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/fonts
#   copying pycbc/results/static/fonts/Lato-Light.woff -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/fonts
#   copying pycbc/results/static/fonts/Lato-Semibold.css -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/static/fonts
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/templates
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/templates/wells
#   copying pycbc/results/templates/wells/two_column.html -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/templates/wells
#   copying pycbc/results/templates/wells/sitemap.html -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/templates/wells
#   copying pycbc/results/templates/orange.html -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/templates
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/results/templates/files
#   copying pycbc/results/templates/files/file_pre.html -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/templates/files
#   copying pycbc/results/templates/files/file_default.html -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/templates/files
#   copying pycbc/results/templates/files/file_img.html -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/templates/files
#   copying pycbc/results/templates/files/file_tmplt.html -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/templates/files
#   copying pycbc/results/templates/files/file_glitchgram.html -> build/lib.macosx-10.6-x86_64-2.7/pycbc/results/templates/files
#   creating build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow/pegasus_files
#   copying pycbc/workflow/pegasus_files/osgconnect-site-template.xml -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow/pegasus_files
#   copying pycbc/workflow/pegasus_files/local-site-template.xml -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow/pegasus_files
#   copying pycbc/workflow/pegasus_files/pegasus-properties.conf -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow/pegasus_files
#   copying pycbc/workflow/pegasus_files/osg-site-template.xml -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow/pegasus_files
#   copying pycbc/workflow/pegasus_files/orangegrid-site-template.xml -> build/lib.macosx-10.6-x86_64-2.7/pycbc/workflow/pegasus_files
#   running build_ext
#   building 'pycbc.waveform.spa_tmplt_cpu' extension
#   creating build/temp.macosx-10.6-x86_64-2.7
#   creating build/temp.macosx-10.6-x86_64-2.7/pycbc
#   creating build/temp.macosx-10.6-x86_64-2.7/pycbc/waveform
#   gcc -fno-strict-aliasing -I/anaconda3/envs/ipykernel_py2/include -arch x86_64 -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/private/var/folders/11/2p7k6f954msg2qh4pzr5ftd40000gn/T/pip-install-9zYL_u/pycbc/.eggs/numpy-1.15.2-py2.7-macosx-10.6-x86_64.egg/numpy/core/include -I/anaconda3/envs/ipykernel_py2/include/python2.7 -c pycbc/waveform/spa_tmplt_cpu.c -o build/temp.macosx-10.6-x86_64-2.7/pycbc/waveform/spa_tmplt_cpu.o -O3 -w -msse4.2 -ffast-math -ffinite-math-only
#   clang: error: no such file or directory: 'pycbc/waveform/spa_tmplt_cpu.c'
#   clang: error: no input files
#   error: command 'gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for pycbc
#   Running setup.py clean for pycbc
#   Building wheel for Mako (setup.py) ... done
#   Stored in directory: /private/var/folders/11/2p7k6f954msg2qh4pzr5ftd40000gn/T/pip-ephem-wheel-cache-F1PV6G/wheels/b3/7b/ae/5addd138cd8175503b9782737bada30d0c88310d08c106f9bf
#   Building wheel for mpld3 (setup.py) ... done
#   Stored in directory: /private/var/folders/11/2p7k6f954msg2qh4pzr5ftd40000gn/T/pip-ephem-wheel-cache-F1PV6G/wheels/c0/47/fb/8a64f89aecfe0059830479308ad42d62e898a3e3cefdf6ba28
#   Building wheel for lscsoft-glue (setup.py) ... done
#   Stored in directory: /private/var/folders/11/2p7k6f954msg2qh4pzr5ftd40000gn/T/pip-ephem-wheel-cache-F1PV6G/wheels/aa/fa/38/d61b002c627ca54f03755b9a288f4b1fa83291608a4bc47b7b
#   Building wheel for emcee (setup.py) ... done
#   Stored in directory: /private/var/folders/11/2p7k6f954msg2qh4pzr5ftd40000gn/T/pip-ephem-wheel-cache-F1PV6G/wheels/2f/5d/a5/78f84e23329ad7d9b1787c9d24371100cae74cdefe25eba50d
#   Building wheel for ligo-segments (setup.py) ... done
#   Stored in directory: /private/var/folders/11/2p7k6f954msg2qh4pzr5ftd40000gn/T/pip-ephem-wheel-cache-F1PV6G/wheels/5d/1e/4a/ab4122baed7d67f6abce65b2b12049d3bc7fe5dad24edf89df
#   Building wheel for weave (setup.py) ... error
#   ERROR: Complete output from command /anaconda3/envs/ipykernel_py2/bin/python -u -c 'import setuptools, tokenize;__file__='"'"'/private/var/folders/11/2p7k6f954msg2qh4pzr5ftd40000gn/T/pip-install-9zYL_u/weave/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/11/2p7k6f954msg2qh4pzr5ftd40000gn/T/pip-wheel-vRA3Im --python-tag cp27:
#   ERROR: Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/private/var/folders/11/2p7k6f954msg2qh4pzr5ftd40000gn/T/pip-install-9zYL_u/weave/setup.py", line 208, in <module>
#       setup_package()
#     File "/private/var/folders/11/2p7k6f954msg2qh4pzr5ftd40000gn/T/pip-install-9zYL_u/weave/setup.py", line 201, in setup_package
#       from numpy.distutils.core import setup
#   ImportError: No module named numpy.distutils.core
#   ----------------------------------------
#   ERROR: Failed building wheel for weave
#   Running setup.py clean for weave
#   Building wheel for pycparser (setup.py) ... done
#   Stored in directory: /private/var/folders/11/2p7k6f954msg2qh4pzr5ftd40000gn/T/pip-ephem-wheel-cache-F1PV6G/wheels/f2/9a/90/de94f8556265ddc9d9c8b271b0f63e57b26fb1d67a45564511
# Successfully built Mako mpld3 lscsoft-glue emcee ligo-segments pycparser
# Failed to build pycbc weave
# Installing collected packages: MarkupSafe, Mako, cython, cycler, numpy, kiwisolver, pytz, subprocess32, backports.functools-lru-cache, pyparsing, matplotlib, pillow, h5py, jinja2, mpld3, asn1crypto, ipaddress, pycparser, cffi, cryptography, pyOpenSSL, ligo-segments, lscsoft-glue, emcee, urllib3, idna, chardet, requests, soupsieve, beautifulsoup4, attrs, more-itertools, funcsigs, py, atomicwrites, pluggy, pytest, astropy, weave, scipy, pycbc, lalsuite, ligo-common
#   Running setup.py install for weave ... done
#   Running setup.py install for pycbc ... done
# Successfully installed Mako-1.0.12 MarkupSafe-1.1.1 asn1crypto-0.24.0 astropy-2.0.14 atomicwrites-1.3.0 attrs-19.1.0 backports.functools-lru-cache-1.5 beautifulsoup4-4.7.1 cffi-1.12.3 chardet-3.0.4 cryptography-2.7 cycler-0.10.0 cython-0.29.10 emcee-2.2.1 funcsigs-1.0.2 h5py-2.9.0 idna-2.8 ipaddress-1.0.22 jinja2-2.10.1 kiwisolver-1.1.0 lalsuite-6.57 ligo-common-1.0.3 ligo-segments-1.2.0 lscsoft-glue-2.0.0 matplotlib-2.2.4 more-itertools-5.0.0 mpld3-0.3 numpy-1.15.2 pillow-6.0.0 pluggy-0.7.1 py-1.8.0 pyOpenSSL-19.0.0 pycbc-1.14.0 pycparser-2.19 pyparsing-2.4.0 pytest-3.6.4 pytz-2019.1 requests-2.22.0 scipy-1.2.2 soupsieve-1.9.1 subprocess32-3.5.4 urllib3-1.25.3 weave-0.17.0

# %%
# %matplotlib inline

# Read in the data around GW150914
from pycbc.catalog import Merger
import pylab

m = Merger('GW150914')

data = {}
for ifo in ['H1', 'L1']:
    data[ifo] = m.strain(ifo)
# Out:
# PyCBC.libutils: pkg-config call failed, setting NO_PKGCONFIG=1
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-2-33f2d3548670> in <module>()
#       5 import pylab
#       6
# ----> 7 m = Merger('GW150914')
#       8
#       9 data = {}
#
# /anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pycbc/catalog/__init__.pyc in __init__(self, name, source)
#      39             The name (GW prefixed date) of the merger event.
#      40         """
# ---> 41         self.data = catalog.get_source(source)[name]
#      42
#      43         # Set some basic params from the dataset
#
# /anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pycbc/catalog/catalog.pyc in get_source(source)
#      40     """
#      41     if source == 'gwtc-1':
# ---> 42         fname = download_file(gwtc1_url, cache=True)
#      43         data = json.load(open(fname, 'r'))
#      44     else:
#
# /anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/astropy/utils/data.pyc in download_file(remote_url, cache, show_progress, timeout)
#    1146             e.reason.strerror = e.reason.strerror + '. requested URL: ' + remote_url
#    1147             e.reason.args = (e.reason.errno, e.reason.strerror)
# -> 1148         raise e
#    1149     except socket.timeout as e:
#    1150         # this isn't supposed to happen, but occasionally a socket.timeout gets
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:727)>
