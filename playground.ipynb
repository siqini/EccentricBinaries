# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.random.random(10)
y = np.random.random(10)

plt.figure()
my_plt = plt.scatter(x,y,c=x+y, s=50, cmap='plasma')
plt.colorbar()
plt.show()
